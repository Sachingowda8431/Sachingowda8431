# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachingowda8431/Sachingowda8431/blob/main/week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[5,21,455,4,8,4,5,51,56,6]
y=[52,56,45,12,78,45,45,42,45,87]

plt.scatter(x,y)
plt.show()

# %%
from sklearn.cluster import KMeans

data=list(zip(x,y))
inertias=[]

for i in range(1,11):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(data)
  inertias.append(kmeans.inertia_)

plt.plot(range(1,11),inertias,marker="o")
plt.title("Elbow method")
plt.xlabel("numbers of clusters")
plt.ylabel("inertia")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(data)
plt.scatter(x,y,c=kmeans.labels_)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
x=[45,45,54,29,65,45,12,75,45,47]
y=[12,45,85,96,12,34,54,82,15,76]

# %%
data1=list(zip(x,y))
print(data)
# Out:
# [(45, 12), (45, 45), (54, 85), (2, 96), (565, 12), (45, 34), (12, 54), (75, 82), (61, 15)]

# %%
inertias=[]

for i in range(1,11):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(data1)
  inertias.append(kmeans.inertia_)

plt.plot(range(1,11),inertias,marker="o")
plt.title("Elbow method")
plt.xlabel("numbers of clusters")
plt.ylabel("inertia")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(data1)
plt.scatter(x,y,c=kmeans.labels_)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X,y=load_breast_cancer(return_X_y=True)

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
inertias=[]

for i in range(1,11):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(X,y)
  inertias.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(X,y,inertias, marker="o")
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %%
import pandas as pd
import random as rm
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/content/Boston_Housing[1].csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATION  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296      15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242      17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242      17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222      18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222      18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
X = pd.DataFrame({
    "RM": np.random.rand(1000) * 200,
    "TAX": np.random.rand(1000) * 600,
})

# %%
k = 17

# %%
Centroids = X.sample(n=k)

# %%
plt.scatter(X["RM"], X["TAX"], c="blue" ,label="Data Points")
plt.scatter(Centroids["RM"], Centroids["TAX"], c="red", marker="X", s=100, label="Centroids")
plt.xlabel("RM")
plt.ylabel("TAX")
plt.legend()
plt.title("Scatter Plot with Centroids")
plt.show()

# %%
diff = 1
j=0

while(diff!=0):
    XD=X
    i=1
    for index1,row_c in Centroids.iterrows():
        ED=[]
        for index2,row_d in XD.iterrows():
            d1=(row_c["RM"]-row_d["RM"])**2
            d2=(row_c["TAX"]-row_d["TAX"])**2
            d=np.sqrt(d1+d2)
            ED.append(d)
        X[i]=ED
        i=i+1

    C=[]
    for index,row in X.iterrows():
        min_dist=row[1]
        pos=1
        for i in range(k):
            if row[i+1] < min_dist:
                min_dist = row[i+1]
                pos=i+1
        C.append(pos)
    X["Cluster"]=C
    Centroids_new = X.groupby(["Cluster"]).mean()[["TAX","RM"]]
    if j == 0:
        diff=1
        j=j+1
    else:
        diff = (Centroids_new['TAX'] - Centroids['RM']).sum() + (Centroids_new['RM'] - Centroids['RM']).sum()
        print(diff.sum())
    Centroids = X.groupby(["Cluster"]).mean()[["TAX","RM"]]
# Out:
# Streaming output truncated to the last 5000 lines.
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# 178.97137343606013
# ...

# %%
color=['blue','green','cyan']
for k in range(k):
    data=X[X["cluster"]==k+1]
    plt.scatter(data["RM"],data["TAX"],c=color[k])
plt.scatter(Centroids["RM"],Centroids["TAX"],c='red')
plt.xlabel('RM')
plt.ylabel('TAX')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

# %%
X,y=load_breast_cancer(return_X_y=True)

# %%
from pandas.core.groupby.groupby import DataFrame
df=DataFrame(X,y)
df.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 0  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 0  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 0  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 0  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9   ...     20     21      22      23      24      25      26      27  \
# 0  0.07871  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 0  0.05667  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 0  0.05999  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 0  0.09744  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 0  0.05883  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29
# 0  0.4601  0.11890
# ...

# %%
df.describe()
# Out:
#                0           1           2            3           4   \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                5           6           7           8           9   ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.104341    0.088799    0.048919    0.181162    0.062798  ...
# std      0.052813    0.079720    0.038803    0.027414    0.007060  ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960  ...
# ...

# %%
scaler=StandardScaler()
data_scaled=scaler.fit_transform(df)
pd.DataFrame(data_scaled).describe()
# Out:
#                  0             1             2             3             4   \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean  -3.153111e-15 -6.568462e-15 -6.993039e-16 -8.553985e-16  6.081447e-15
# std    1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00 -1.984504e+00 -1.454443e+00 -3.112085e+00
# 25%   -6.893853e-01 -7.259631e-01 -6.919555e-01 -6.671955e-01 -7.109628e-01
# 50%   -2.150816e-01 -1.046362e-01 -2.359800e-01 -2.951869e-01 -3.489108e-02
# 75%    4.693926e-01  5.841756e-01  4.996769e-01  3.635073e-01  6.361990e-01
# max    3.971288e+00  4.651889e+00  3.976130e+00  5.250529e+00  4.770911e+00
#
#                  5             6             7             8             9   \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean  -1.136369e-15 -2.997017e-16  1.023981e-15 -1.860648e-15 -1.504752e-15
# ...

# %%
kmeans=KMeans(n_clusters=2,init="k-means++")
kmeans.fit(data_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
kmeans.inertia_
# Out:
# 11595.461473962354

# %%
SSE=[]
for cluster in range(1,20):
  kmeans=KMeans(n_clusters=cluster,init="k-means++")
  kmeans.fit(data_scaled)
  SSE.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
frame=pd.DataFrame({"cluster":range(1,20), "SSE":SSE})
plt.figure(figsize=(12,6))
plt.plot(frame["cluster"],frame["SSE"],marker="o")
plt.xlabel("number of clusters")
plt.ylabel("interia")
# Out:
# Text(0, 0.5, 'interia')

# %%
kmeans = KMeans(n_clusters = 5, init='k-means++')
kmeans.fit(data_scaled)
pred = kmeans.predict(data_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
frame = pd.DataFrame(data_scaled)
frame['cluster'] = pred
frame['cluster'].value_counts()
# Out:
# 2    218
# 1    147
# 0     98
# 3     69
# 4     37
# Name: cluster, dtype: int64

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

data = load_iris()
X = data.data

n_clusters = 3

kmeans = KMeans(n_clusters=n_clusters, random_state=42)

kmeans.fit(X)

inertia = kmeans.inertia_
print("Inertia:", inertia)
# Out:
# Inertia: 78.851441426146
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics import pairwise_distances
import itertools

cluster_centers = kmeans.cluster_centers_
inter_cluster_distances = pairwise_distances(cluster_centers, metric='euclidean')

intra_cluster_distances = []
labels = kmeans.labels_
for i in range(n_clusters):
    cluster_points = X[labels == i]
    if len(cluster_points) > 1:
      distances = pairwise_distances(cluster_points, metric='euclidean')
      max_intra_distance = np.max(distances)
      intra_cluster_distances.append(max_intra_distance)

dunn_index = np.max(inter_cluster_distances) / np.max(intra_cluster_distances)
print("Dunn Index:", dunn_index)
# Out:
# Dunn Index: 1.873845301364835

# %%
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd


df=pd.read_csv("/content/Boston_Housing[1].csv")
X = df.drop(columns=["TAX"])

n_clusters = 3

kmeans = KMeans(n_clusters=n_clusters, random_state=42)

kmeans.fit(X)

inertia = kmeans.inertia_
print("Inertia:", inertia)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Inertia: 859080.9965313978

# %%
from sklearn.metrics import pairwise_distances
import itertools

cluster_centers = kmeans.cluster_centers_
inter_cluster_distances = pairwise_distances(cluster_centers, metric='euclidean')

intra_cluster_distances = []
labels = kmeans.labels_
for i in range(n_clusters):
    cluster_points = X[labels == i]
    if len(cluster_points) > 1:
      distances = pairwise_distances(cluster_points, metric='euclidean')
      max_intra_distance = np.max(distances)
      intra_cluster_distances.append(max_intra_distance)

dunn_index = np.max(inter_cluster_distances) / np.max(intra_cluster_distances)
print("Dunn Index:", dunn_index)
# Out:
# Dunn Index: 1.5770702315781744

# %%
#PCA
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt

# %%
X,y=load_breast_cancer(return_X_y=True)

# %%
mean = np.mean(X, axis=0)
std = np.std(X, axis=0)
X_standardized = (X - mean) / std

# %%
n_components = 2
pca = PCA(n_components=n_components)

# %%
X_reduced = pca.fit_transform(X_standardized)

# %%
explained_variance_ratio = pca.explained_variance_ratio_
print("Explained Variance Ratios:", explained_variance_ratio)
# Out:
# Explained Variance Ratios: [0.44272026 0.18971182]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset')
plt.colorbar(label='Target Class')
plt.show()
